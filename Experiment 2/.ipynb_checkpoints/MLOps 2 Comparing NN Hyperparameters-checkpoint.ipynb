# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense,Input,Flatten,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time

# %%
HIDDEN_LAYERS = [1,2,3]
NEURONS = [64,128,256]
ACTIVATION = 'relu'
OPTIMIZERS = Adam
LEARNING_RATE = 0.001
BATCH_SIZE = 32
EPOCHS = 10
DROPOUT_PROB = [0,0.3]

# %%
(x_train_full,y_train_full),(x_test,y_test) = fashion_mnist.load_data()

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train_full,y_train_full,test_size=0.2,random_state=42,stratify=y_train_full)

# %%
plt.figure(figsize=(7,7))
for i in range(7):
    plt.subplot(3,4,i+1)
    plt.imshow(x_train[i],cmap='gray')
    plt.axis("off")
    plt.title(f"Class {y_train[i]}")
    plt.tight_layout()

plt.show()

# %%
len(x_train)
# Out:
# 48000

# %%
x_train_norm = x_train.astype("float32")/255.0
x_test_norm = x_test.astype("float32")/255.0
x_val_norm = x_val.astype("float32")/255.0

# %%
y_train = to_categorical(y_train,num_classes=10)
y_test = to_categorical(y_test,num_classes=10)
y_val = to_categorical(y_val,num_classes=10)

# %%
def build_and_train_model(x,y,HIDDEN_LAYERS,NEURONS,ACTIVATION,OPTIMIZER,LEARNING_RATE,BATCH_SIZE,EPOCHS,DROPOUT_PROB,VALIDATION_DATA):
    model = Sequential([Input(shape=(28,28))])
    model.add(Flatten())
    for i in range(HIDDEN_LAYERS):
        model.add(Dense(NEURONS,activation=ACTIVATION))
    if DROPOUT_PROB > 0:
        model.add(Dropout(DROPOUT_PROB))
    model.add(Dense(10,activation='softmax'))
    model.compile(optimizer=OPTIMIZER(learning_rate=LEARNING_RATE),loss='categorical_crossentropy',metrics=['accuracy'])
    history = model.fit(x,y,epochs=EPOCHS,batch_size=BATCH_SIZE,validation_data=VALIDATION_DATA)
    return model,history

# %%
x_train_norm.shape
# Out:
# (48000, 28, 28)

# %%
y_train.shape
# Out:
# (48000, 10)

# %%
import mlflow
mlflow.set_tracking_uri(uri="http://localhost:5000")

# %%
mlflow.set_experiment("MLOps Experiment 2 - Comparing Neural Networks with different Hyperparameters")
# Out:
# 2026/08/01 23:29:23 INFO mlflow.tracking.fluent: Experiment with name 'MLOps Experiment 2 - Comparing Neural Networks with different Hyperparameters' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/447822412696860658', creation_time=1785607163195, experiment_id='447822412696860658', last_update_time=1785607163195, lifecycle_stage='active', name='MLOps Experiment 2 - Comparing Neural Networks with different Hyperparameters', tags={}>

# %%
result = {}
i = 1

# %%
for h in HIDDEN_LAYERS:
    for n in NEURONS:
        for drop in DROPOUT_PROB:
            print(f"Training Model {i}/{len(HIDDEN_LAYERS)*len(NEURONS)*len(DROPOUT_PROB)}")
            parameters_results = {}
            start_time = time.time()
            model,history = build_and_train_model(x=x_train_norm,y=y_train,HIDDEN_LAYERS=h,NEURONS=n,ACTIVATION=ACTIVATION,OPTIMIZER=OPTIMIZERS,LEARNING_RATE=LEARNING_RATE,BATCH_SIZE=BATCH_SIZE,EPOCHS=EPOCHS,DROPOUT_PROB=drop,VALIDATION_DATA=(x_val_norm,y_val))
            end_time = time.time()
            test_loss,test_accuracy = model.evaluate(x_test_norm,y_test)
            hyperparameters = {
                'HIDDEN_LAYERS' : h,
                'NEURONS' : n,
                'ACTIVATION' : ACTIVATION,
                'OPTIMIZER' : "Adam",
                'LEARNING_RATE' : LEARNING_RATE,
                'BATCH_SIZE' : BATCH_SIZE,
                'EPOCHS' : EPOCHS,
                'DROPOUT' : drop
            }
            metrics = {
                'TRAINING_ACCURACY' : history.history['accuracy'][-1],
                'TRAINING_LOSS' : history.history['loss'][-1],
                'VAL_ACCURACY' : history.history['val_accuracy'][-1],
                'VAL_LOSS' : history.history['val_loss'][-1],
                'TEST_ACCURACY' : test_accuracy,
                'TEST_LOSS' : test_loss,
                'MODEL_RUN_TIME' : end_time-start_time
            }
            model_name = f"Model {i}"
            with mlflow.start_run(run_name=model_name):
                mlflow.log_params(hyperparameters)
                mlflow.log_metrics(metrics)
                mlflow.log_model(model,model_name)
            result[model_name] = hyperparameters|metrics
            i = i+1
print(f"{len(HIDDEN_LAYERS)*len(NEURONS)*len(DROPOUT_PROB)} Models Trained successfully")
# Out:
# Training Model 1/18
# Epoch 1/10
# 1500/1500 [==============================] - 10s 4ms/step - loss: 0.5437 - accuracy: 0.8122 - val_loss: 0.4461 - val_accuracy: 0.8415
# Epoch 2/10
#   50/1500 [>.............................] - ETA: 5s - loss: 0.3802 - accuracy: 0.8625

# %%
result
# Out:
# {'Model 1': {'HIDDEN_LAYERS': 1,
#   'NEURONS': 64,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.8989583253860474,
#   'TRAINING_LOSS': 0.2687230110168457,
#   'VAL_ACCURACY': 0.878083348274231,
#   'VAL_LOSS': 0.34274056553840637,
#   'TEST_ACCURACY': 0.8633999824523926,
#   'TEST_LOSS': 0.38538601994514465,
#   'MODEL_RUN_TIME': 108.07191038131714},
#  'Model 2': {'HIDDEN_LAYERS': 1,
#   'NEURONS': 64,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.8709375262260437,
#   'TRAINING_LOSS': 0.34730640053749084,
#   'VAL_ACCURACY': 0.8838333487510681,
#   'VAL_LOSS': 0.32594794034957886,
#   'TEST_ACCURACY': 0.870199978351593,
#   'TEST_LOSS': 0.36206695437431335,
#   'MODEL_RUN_TIME': 106.17381024360657},
#  'Model 3': {'HIDDEN_LAYERS': 1,
#   'NEURONS': 128,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.9081666469573975,
#   'TRAINING_LOSS': 0.24649104475975037,
#   'VAL_ACCURACY': 0.8881666660308838,
#   'VAL_LOSS': 0.3212208151817322,
#   'TEST_ACCURACY': 0.8763999938964844,
#   'TEST_LOSS': 0.3572371304035187,
#   'MODEL_RUN_TIME': 120.78112936019897},
#  'Model 4': {'HIDDEN_LAYERS': 1,
#   'NEURONS': 128,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.8852708339691162,
#   'TRAINING_LOSS': 0.30911049246788025,
#   'VAL_ACCURACY': 0.8829166889190674,
#   'VAL_LOSS': 0.3190690577030182,
#   'TEST_ACCURACY': 0.8733000159263611,
#   'TEST_LOSS': 0.35596469044685364,
#   'MODEL_RUN_TIME': 142.76883554458618},
#  'Model 5': {'HIDDEN_LAYERS': 1,
#   'NEURONS': 256,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.9127708077430725,
#   'TRAINING_LOSS': 0.23145490884780884,
#   'VAL_ACCURACY': 0.8923333287239075,
#   'VAL_LOSS': 0.30078399181365967,
#   'TEST_ACCURACY': 0.883899986743927,
#   'TEST_LOSS': 0.32946664094924927,
#   'MODEL_RUN_TIME': 116.36324858665466},
#  'Model 6': {'HIDDEN_LAYERS': 1,
#   'NEURONS': 256,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.8904374837875366,
#   'TRAINING_LOSS': 0.2924559414386749,
#   'VAL_ACCURACY': 0.8830833435058594,
#   'VAL_LOSS': 0.32390326261520386,
#   'TEST_ACCURACY': 0.8690000176429749,
#   'TEST_LOSS': 0.35804837942123413,
#   'MODEL_RUN_TIME': 81.63836312294006},
#  'Model 7': {'HIDDEN_LAYERS': 2,
#   'NEURONS': 64,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.9041249752044678,
#   'TRAINING_LOSS': 0.2568764388561249,
#   'VAL_ACCURACY': 0.8916666507720947,
#   'VAL_LOSS': 0.31261223554611206,
#   'TEST_ACCURACY': 0.8809999823570251,
#   'TEST_LOSS': 0.3456704616546631,
#   'MODEL_RUN_TIME': 75.85829710960388},
#  'Model 8': {'HIDDEN_LAYERS': 2,
#   'NEURONS': 64,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.8922291398048401,
#   'TRAINING_LOSS': 0.2885720133781433,
#   'VAL_ACCURACY': 0.8811666369438171,
#   'VAL_LOSS': 0.32468315958976746,
#   'TEST_ACCURACY': 0.8676999807357788,
#   'TEST_LOSS': 0.366010457277298,
#   'MODEL_RUN_TIME': 82.66258215904236},
#  'Model 9': {'HIDDEN_LAYERS': 2,
#   'NEURONS': 128,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.9100208282470703,
#   'TRAINING_LOSS': 0.23769809305667877,
#   'VAL_ACCURACY': 0.8854166865348816,
#   'VAL_LOSS': 0.326919287443161,
#   'TEST_ACCURACY': 0.873199999332428,
#   'TEST_LOSS': 0.3550824522972107,
#   'MODEL_RUN_TIME': 82.65463328361511},
#  'Model 10': {'HIDDEN_LAYERS': 2,
#   'NEURONS': 128,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.9021250009536743,
#   'TRAINING_LOSS': 0.26121580600738525,
#   'VAL_ACCURACY': 0.8829166889190674,
#   'VAL_LOSS': 0.34443122148513794,
#   'TEST_ACCURACY': 0.8715000152587891,
#   'TEST_LOSS': 0.3775067925453186,
#   'MODEL_RUN_TIME': 81.59553742408752},
#  'Model 11': {'HIDDEN_LAYERS': 2,
#   'NEURONS': 256,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.914145827293396,
#   'TRAINING_LOSS': 0.22743916511535645,
#   'VAL_ACCURACY': 0.8859999775886536,
#   'VAL_LOSS': 0.3284529149532318,
#   'TEST_ACCURACY': 0.8795999884605408,
#   'TEST_LOSS': 0.35682523250579834,
#   'MODEL_RUN_TIME': 79.69832587242126},
#  'Model 12': {'HIDDEN_LAYERS': 2,
#   'NEURONS': 256,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.9055416584014893,
#   'TRAINING_LOSS': 0.24786832928657532,
#   'VAL_ACCURACY': 0.8872500061988831,
#   'VAL_LOSS': 0.32325419783592224,
#   'TEST_ACCURACY': 0.8748000264167786,
#   'TEST_LOSS': 0.3547828197479248,
#   'MODEL_RUN_TIME': 142.6874885559082},
#  'Model 13': {'HIDDEN_LAYERS': 3,
#   'NEURONS': 64,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.9023958444595337,
#   'TRAINING_LOSS': 0.25799429416656494,
#   'VAL_ACCURACY': 0.8823333382606506,
#   'VAL_LOSS': 0.33349528908729553,
#   'TEST_ACCURACY': 0.8741999864578247,
#   'TEST_LOSS': 0.3703046441078186,
#   'MODEL_RUN_TIME': 142.67970776557922},
#  'Model 14': {'HIDDEN_LAYERS': 3,
#   'NEURONS': 64,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.8946250081062317,
#   'TRAINING_LOSS': 0.284111887216568,
#   'VAL_ACCURACY': 0.887499988079071,
#   'VAL_LOSS': 0.3279750645160675,
#   'TEST_ACCURACY': 0.8774999976158142,
#   'TEST_LOSS': 0.3565208911895752,
#   'MODEL_RUN_TIME': 142.86263728141785},
#  'Model 15': {'HIDDEN_LAYERS': 3,
#   'NEURONS': 128,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.9089999794960022,
#   'TRAINING_LOSS': 0.23985397815704346,
#   'VAL_ACCURACY': 0.8879166841506958,
#   'VAL_LOSS': 0.321584016084671,
#   'TEST_ACCURACY': 0.8798999786376953,
#   'TEST_LOSS': 0.3498154878616333,
#   'MODEL_RUN_TIME': 142.75385522842407},
#  'Model 16': {'HIDDEN_LAYERS': 3,
#   'NEURONS': 128,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.9021875262260437,
#   'TRAINING_LOSS': 0.2572002410888672,
#   'VAL_ACCURACY': 0.8862500190734863,
#   'VAL_LOSS': 0.3368144929409027,
#   'TEST_ACCURACY': 0.8769999742507935,
#   'TEST_LOSS': 0.3672490417957306,
#   'MODEL_RUN_TIME': 136.11340713500977},
#  'Model 17': {'HIDDEN_LAYERS': 3,
#   'NEURONS': 256,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0,
#   'TRAINING_ACCURACY': 0.9098125100135803,
#   'TRAINING_LOSS': 0.23376332223415375,
#   'VAL_ACCURACY': 0.8974999785423279,
#   'VAL_LOSS': 0.3097097873687744,
#   'TEST_ACCURACY': 0.8885999917984009,
#   'TEST_LOSS': 0.3421778082847595,
#   'MODEL_RUN_TIME': 148.16546249389648},
#  'Model 18': {'HIDDEN_LAYERS': 3,
#   'NEURONS': 256,
#   'ACTIVATION': 'relu',
#   'OPTIMIZER': 'Adam',
#   'LEARNING_RATE': 0.001,
#   'BATCH_SIZE': 32,
#   'EPOCHS': 10,
#   'DROPOUT': 0.3,
#   'TRAINING_ACCURACY': 0.9056666493415833,
#   'TRAINING_LOSS': 0.248531773686409,
#   'VAL_ACCURACY': 0.8860833048820496,
#   'VAL_LOSS': 0.335265189409256,
#   'TEST_ACCURACY': 0.8792999982833862,
#   'TEST_LOSS': 0.35647180676460266,
#   'MODEL_RUN_TIME': 142.63654160499573}}

# %%
import pandas as pd
df = pd.DataFrame(result).T
df
# Out:
#          HIDDEN_LAYERS NEURONS ACTIVATION OPTIMIZER LEARNING_RATE BATCH_SIZE  \
# Model 1              1      64       relu      Adam         0.001         32
# Model 2              1      64       relu      Adam         0.001         32
# Model 3              1     128       relu      Adam         0.001         32
# Model 4              1     128       relu      Adam         0.001         32
# Model 5              1     256       relu      Adam         0.001         32
# Model 6              1     256       relu      Adam         0.001         32
# Model 7              2      64       relu      Adam         0.001         32
# Model 8              2      64       relu      Adam         0.001         32
# Model 9              2     128       relu      Adam         0.001         32
# Model 10             2     128       relu      Adam         0.001         32
# Model 11             2     256       relu      Adam         0.001         32
# Model 12             2     256       relu      Adam         0.001         32
# Model 13             3      64       relu      Adam         0.001         32
# Model 14             3      64       relu      Adam         0.001         32
# Model 15             3     128       relu      Adam         0.001         32
# Model 16             3     128       relu      Adam         0.001         32
# Model 17             3     256       relu      Adam         0.001         32
# Model 18             3     256       relu      Adam         0.001         32
#
#          EPOCHS DROPOUT TRAINING_ACCURACY TRAINING_LOSS VAL_ACCURACY  \
# Model 1      10       0          0.898958      0.268723     0.878083
# Model 2      10     0.3          0.870938      0.347306     0.883833
# Model 3      10       0          0.908167      0.246491     0.888167
# Model 4      10     0.3          0.885271       0.30911     0.882917
# Model 5      10       0          0.912771      0.231455     0.892333
# Model 6      10     0.3          0.890437      0.292456     0.883083
# Model 7      10       0          0.904125      0.256876     0.891667
# Model 8      10     0.3          0.892229      0.288572     0.881167
# Model 9      10       0          0.910021      0.237698     0.885417
# Model 10     10     0.3          0.902125      0.261216     0.882917
# Model 11     10       0          0.914146      0.227439        0.886
# Model 12     10     0.3          0.905542      0.247868      0.88725
# Model 13     10       0          0.902396      0.257994     0.882333
# Model 14     10     0.3          0.894625      0.284112       0.8875
# Model 15     10       0             0.909      0.239854     0.887917
# Model 16     10     0.3          0.902188        0.2572      0.88625
# Model 17     10       0          0.909813      0.233763       0.8975
# Model 18     10     0.3          0.905667      0.248532     0.886083
#
#           VAL_LOSS TEST_ACCURACY TEST_LOSS MODEL_RUN_TIME
# Model 1   0.342741        0.8634  0.385386      108.07191
# Model 2   0.325948        0.8702  0.362067      106.17381
# Model 3   0.321221        0.8764  0.357237     120.781129
# Model 4   0.319069        0.8733  0.355965     142.768836
# Model 5   0.300784        0.8839  0.329467     116.363249
# Model 6   0.323903         0.869  0.358048      81.638363
# Model 7   0.312612         0.881   0.34567      75.858297
# Model 8   0.324683        0.8677   0.36601      82.662582
# Model 9   0.326919        0.8732  0.355082      82.654633
# Model 10  0.344431        0.8715  0.377507      81.595537
# Model 11  0.328453        0.8796  0.356825      79.698326
# Model 12  0.323254        0.8748  0.354783     142.687489
# Model 13  0.333495        0.8742  0.370305     142.679708
# Model 14  0.327975        0.8775  0.356521     142.862637
# Model 15  0.321584        0.8799  0.349815     142.753855
# Model 16  0.336814         0.877  0.367249     136.113407
# Model 17   0.30971        0.8886  0.342178     148.165462
# Model 18  0.335265        0.8793  0.356472     142.636542

# %%
df.to_csv("hyperparameter_results.csv", index=False)

# %%
import mlflow

# %%
mlflow.set_tracking_uri(uri="http://localhost:5000")

# %%
mlflow.set_experiment("")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/364495864761260798', creation_time=1785605233844, experiment_id='364495864761260798', last_update_time=1785605233844, lifecycle_stage='active', name='MLOps Experiment 2 - Comparing Neural Networks Hyperparameters', tags={}>

# %%
for i in range(len(result)):
    model_name = f"Model {i+1}"
    hyperparameters = df.iloc[i,0:8].to_dict()
    metrics = df.iloc[i,8:].to_dict()
    with mlflow.start_run(run_name=model_name):
        mlflow.log_params(hyperparameters)
        mlflow.log_metrics(metrics)
        mlflow.tensorflow.log_model(model,)

# %%
df.iloc[11,:8]
# Out:
# HIDDEN_LAYERS        2
# NEURONS            256
# ACTIVATION        relu
# OPTIMIZER         Adam
# LEARNING_RATE    0.001
# BATCH_SIZE          32
# EPOCHS              10
# DROPOUT            0.3
# Name: Model 12, dtype: object
